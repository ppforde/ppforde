# %%
using CSV, Queryverse, Plots

# %%
fname = "/home/gda/Downloads/AMD.csv"
# Out:
# "/home/gda/Downloads/AMD.csv"

# %%
df = CSV.read(fname, DataFrame, normalizenames=true)
# Out:
# 252×7 DataFrame
#  Row │ Date        Open     High     Low      Close    Adj_Close  Volume
#      │ Date…       Float64  Float64  Float64  Float64  Float64    Int64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ 2020-12-21    94.25    95.28    91.08    93.23      93.23  47093900
#    2 │ 2020-12-22    93.36    93.55    90.53    93.16      93.16  35673700
#    3 │ 2020-12-23    93.08    93.13    91.46    91.55      91.55  25993300
#    4 │ 2020-12-24    91.8     92.51    91.31    91.81      91.81  16705900
#    5 │ 2020-12-28    92.93    93.14    90.82    91.6       91.6   30627300
#    6 │ 2020-12-29    91.66    92.46    89.43    90.62      90.62  31748200
#    7 │ 2020-12-30    90.78    92.85    90.19    92.29      92.29  25845000
#    8 │ 2020-12-31    92.1     92.3     90.87    91.71      91.71  24930700
#    9 │ 2021-01-04    92.11    96.06    90.92    92.3       92.3   51802600
# ...

# %%
first(df, 5)
# Out:
# 5×7 DataFrame
#  Row │ Date        Open     High     Low      Close    Adj_Close  Volume
#      │ Date…       Float64  Float64  Float64  Float64  Float64    Int64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ 2020-12-21    94.25    95.28    91.08    93.23      93.23  47093900
#    2 │ 2020-12-22    93.36    93.55    90.53    93.16      93.16  35673700
#    3 │ 2020-12-23    93.08    93.13    91.46    91.55      91.55  25993300
#    4 │ 2020-12-24    91.8     92.51    91.31    91.81      91.81  16705900
#    5 │ 2020-12-28    92.93    93.14    90.82    91.6       91.6   30627300

# %%
last(df, 5)
# Out:
# 5×7 DataFrame
#  Row │ Date        Open     High     Low      Close    Adj_Close  Volume
#      │ Date…       Float64  Float64  Float64  Float64  Float64    Int64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │ 2021-12-14   131.67   137.24   130.6    135.6      135.6   50754600
#    2 │ 2021-12-15   135.11   146.69   133.81   146.5      146.5   72425800
#    3 │ 2021-12-16   147.0    147.93   137.02   138.64     138.64  63369600
#    4 │ 2021-12-17   136.3    142.04   136.11   137.75     137.75  55642100
#    5 │ 2021-12-20   135.97   138.0    133.52   135.8      135.8   38195222

# %%
df = last(df, 30)
# Out:
# 30×7 DataFrame
#  Row │ Date        Open     High     Low      Close    Adj_Close  Volume
#      │ Date…       Float64  Float64  Float64  Float64  Float64    Int64
# ─────┼──────────────────────────────────────────────────────────────────────
#    1 │ 2021-11-08   137.7    153.6    137.7    150.16     150.16  141493800
#    2 │ 2021-11-09   154.01   155.65   143.89   148.92     148.92   98442600
#    3 │ 2021-11-10   143.93   146.3    138.52   139.87     139.87   82989200
#    4 │ 2021-11-11   142.96   146.47   140.84   146.01     146.01   67934800
#    5 │ 2021-11-12   146.03   148.59   144.25   147.89     147.89   52124200
#    6 │ 2021-11-15   148.0    148.98   142.86   146.49     146.49   52271300
#    7 │ 2021-11-16   145.93   153.08   145.34   152.45     152.45   53100800
#    8 │ 2021-11-17   151.98   154.66   149.69   151.34     151.34   54527500
#    9 │ 2021-11-18   157.07   158.89   152.56   155.02     155.02   60612700
# ...

# %%
p1 = histogram(df.Close)
p2 = scatter(df.Close, df.Volume)
p3 = plot(df.Date, df.Close)
p4 = plot(df.Date, df.Volume)

plot(p1, p2, p3, p4, layout=(4, 1), legend=false)

# %%
scatter(df.Close, df.Volume)

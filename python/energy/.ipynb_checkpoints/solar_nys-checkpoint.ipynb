# %% [markdown]
# # Solar Electric Programs Reported by NYSERDA
# ---

# %% [markdown]
# **Purpose:**
#
# * End-to-end exploratory data analysis
# * Explore challenges with using dates
#
# **Data Source:**
#
# https://data.ny.gov/

# %%
# system libraries
import os
import sys

# check system information
print('Python Information', sys.version)
print('This is your current directory', os.getcwd())
# Out:
# Python Information 3.8.3 (default, Jul  2 2020, 16:21:59)
# [GCC 7.3.0]
# This is your current directory /home/gda/Documents/github/ppforde/python/energy

# %%
# datetime libraries
import datetime

# assgin current date and time
currentDate = datetime.date.today()
currentTime = datetime.datetime.now()

# check datetime information
print('Today is {}'.format(currentDate))
print('Today is', datetime.datetime.strftime(currentDate, '%m/%d/%Y'))
print('The time is', datetime.datetime.strftime(currentTime, '%H:%M:%S'))
# Out:
# Today is 2021-12-23
# Today is 12/23/2021
# The time is 22:16:43

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.precision',2)
pd.set_option('max_rows',100)
pd.set_option('max_columns',100)

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style('dark')

print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 1.0.5
# 1.18.5
# 0.11.2

# %%
from dateutil import parser
import glob

# %%
dates = ['07/31/2016', '7/31/16', '31-07-2016', '31-JUL-2016', '2016-07-31', 'July 31st, 2016', 'Jul.16', 'July.2016']

for d in dates:
    print(parser.parse(d))
# Out:
# 2016-07-31 00:00:00
# 2016-07-31 00:00:00
# 2016-07-31 00:00:00
# 2016-07-31 00:00:00
# 2016-07-31 00:00:00
# 2016-07-31 00:00:00
# 2021-07-16 00:00:00
# 2016-07-23 00:00:00

# %%
dates = ['Reporting Period', 'Date Application Received', 'Date Completed']

filename = 'https://data.ny.gov/api/views/3x8r-34rs/rows.csv?accessType=DOWNLOAD&sorting=true'

df = pd.read_csv(filename, parse_dates=dates)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126090 entries, 0 to 126089
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   Reporting Period                       126090 non-null  datetime64[ns]
#  1   Project Number                         126090 non-null  object
#  2   Legacy Project Number                  55293 non-null   object
#  3   City                                   126090 non-null  object
#  4   County                                 125674 non-null  object
#  5   State                                  126090 non-null  object
#  6   Zip Code                               126090 non-null  int64
#  7   Sector                                 126090 non-null  object
#  8   Program Type                           126090 non-null  object
#  9   Solicitation                           126090 non-null  object
#  10  Electric Utility                       126046 non-null  object
#  11  Purchase Type                          120601 non-null  object
#  12  Date Application Received              126090 non-null  datetime64[ns]
#  13  Date Completed                         119636 non-null  datetime64[ns]
#  14  Project Status                         126090 non-null  object
#  15  Contractor                             116434 non-null  object
#  16  Primary Inverter Manufacturer          122002 non-null  object
#  17  Primary Inverter Model Number          113150 non-null  object
#  18  Total Inverter Quantity                125974 non-null  float64
#  19  Primary PV Module Manufacturer         122047 non-null  object
#  20  PV Module Model Number                 113137 non-null  object
#  21  Total PV Module Quantity               125967 non-null  float64
#  22  Project Cost                           126090 non-null  float64
#  23  $Incentive                             122095 non-null  float64
#  24  Total Nameplate kW DC                  126090 non-null  float64
#  25  Expected KWh Annual Production         126025 non-null  float64
#  26  Remote Net Metering                    44968 non-null   object
#  27  Affordable Solar                       126090 non-null  object
#  28  Community Distributed Generation       126090 non-null  object
#  29  Green Jobs Green New York Participant  126090 non-null  object
#  30  Georeference                           126090 non-null  object
# dtypes: datetime64[ns](3), float64(6), int64(1), object(21)
# memory usage: 29.8+ MB

# %%
df.columns = df.columns.str.lower().str.replace(" ","_").str.replace("$","")
df.columns
# Out:
# Index(['reporting_period', 'project_number', 'legacy_project_number', 'city',
#        'county', 'state', 'zip_code', 'sector', 'program_type', 'solicitation',
#        'electric_utility', 'purchase_type', 'date_application_received',
#        'date_completed', 'project_status', 'contractor',
#        'primary_inverter_manufacturer', 'primary_inverter_model_number',
#        'total_inverter_quantity', 'primary_pv_module_manufacturer',
#        'pv_module_model_number', 'total_pv_module_quantity', 'project_cost',
#        'incentive', 'total_nameplate_kw_dc', 'expected_kwh_annual_production',
#        'remote_net_metering', 'affordable_solar',
#        'community_distributed_generation',
#        'green_jobs_green_new_york_participant', 'georeference'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   reporting_period    project_number legacy_project_number              city  \
# 0       2021-11-30        0000002557                2035-1       Dobbs Ferry
# 1       2021-11-30        0000000275           01001-00017    Highland Falls
# 2       2021-11-30  2011-158775-SLPR                   NaN           Montauk
# 3       2021-11-30        0000353026                   NaN  Croton On Hudson
# 4       2021-11-30  2011-156499-SLPR                   NaN           Shirley
# 5       2021-11-30        0000321013                   NaN             Bronx
# 6       2021-11-30        0000234406                   NaN            Queens
# 7       2021-11-30        0000330220                   NaN          Lakewood
# 8       2021-11-30  2011-157819-SLPR                   NaN         Manhasset
# 9       2021-11-30  2011-157191-SLPR                   NaN        Water Mill
#
#         county state  zip_code           sector                  program_type  \
# 0          NaN    NY     10522  Non-Residential  Residential/Small Commercial
# 1       Orange    NY     10928  Non-Residential  Residential/Small Commercial
# 2      Suffolk    NY     11954      Residential  Residential/Small Commercial
# 3  Westchester    NY     10520      Residential  Residential/Small Commercial
# 4      Suffolk    NY     11967      Residential  Residential/Small Commercial
# 5        Bronx    NY     10457      Residential  Residential/Small Commercial
# 6       Queens    NY     11361      Residential  Residential/Small Commercial
# 7   Chautauqua    NY     14750      Residential  Residential/Small Commercial
# 8       Nassau    NY     11030      Residential  Residential/Small Commercial
# 9      Suffolk    NY     11976      Residential  Residential/Small Commercial
#
#             solicitation             electric_utility purchase_type  \
# 0          ARRA Projects          Consolidated Edison           NaN
# 1               PON 1184                          NaN           NaN
# 2  SLPR 2010 Residential  Long Island Power Authority      Purchase
# 3               PON 2112          Consolidated Edison      Purchase
# 4  SLPR 2010 Residential  Long Island Power Authority      Purchase
# 5               PON 2112          Consolidated Edison      Purchase
# 6               PON 2112          Consolidated Edison         Lease
# 7               PON 2112                National Grid      Purchase
# 8  SLPR 2010 Residential  Long Island Power Authority      Purchase
# 9  SLPR 2010 Residential  Long Island Power Authority      Purchase
#
#   date_application_received date_completed project_status         contractor  \
# 0                2011-12-15     2011-12-15       Complete                NaN
# 1                2003-08-02     2005-05-24       Complete  Solar Works, Inc.
# 2                2008-10-01     2008-10-01       Complete                NaN
# 3                2021-11-30            NaT       Pipeline                NaN
# 4                2002-11-18     2002-11-18       Complete                NaN
# 5                2021-09-21            NaT       Pipeline                NaN
# 6                2020-02-15     2020-03-24       Complete        SunRun Inc.
# 7                2021-10-12            NaT       Pipeline                NaN
# 8                2008-01-18     2008-01-18       Complete                NaN
# 9                2006-05-11     2006-05-11       Complete                NaN
#
#   primary_inverter_manufacturer primary_inverter_model_number  \
# 0                    PV Powered                   PVP50KW-208
# 1                   Fronius USA                    IG 2500-LV
# 2                           NaN                           NaN
# 3                    Tesla Inc.           1538000-xx-y [240V]
# 4                           NaN                           NaN
# 5   SolarEdge Technologies Ltd.             SE6000H-US [240V]
# 6             Delta Electronics               M4-TL-US [240V]
# 7                      SunPower       SPR-X22-360-E-AC [240V]
# 8                           NaN                           NaN
# 9                           NaN                           NaN
#
#    total_inverter_quantity primary_pv_module_manufacturer  \
# 0                     1.00                          Sharp
# 1                     1.00                       BP Solar
# 2                     0.00                            NaN
# 3                     1.00                     Tesla Inc.
# 4                     0.00                            NaN
# 5                     1.00                      REC Solar
# 6                     2.00                      REC Solar
# 7                    17.00                       SunPower
# 8                     0.00                            NaN
# 9                     0.00                            NaN
#
#   pv_module_model_number  total_pv_module_quantity  project_cost  incentive  \
# 0              NU-U240F1                    204.00          0.00        nan
# 1                BP3125S                     16.00          0.00        nan
# 2                    NaN                      0.00     34,109.00   1,020.00
# 3                 SR72T1                    112.00     41,453.81   1,613.00
# 4                    NaN                      0.00      2,455.00   1,650.00
# 5            REC440AA 72                     19.00     42,000.00   1,672.00
# 6             REC310TP2M                     29.00     19,706.00   1,798.00
# 7       SPR-X22-360-E-AC                     17.00     18,360.00   2,142.00
# 8                    NaN                      0.00      6,000.00   2,160.00
# 9                    NaN                      0.00     10,000.00   2,240.00
#
#    total_nameplate_kw_dc  expected_kwh_annual_production remote_net_metering  \
# 0                  48.96                       52,433.00                 NaN
# 1                   2.00                             nan                 NaN
# 2                   0.27                          317.00                 NaN
# 3                   8.06                        8,323.00                 NaN
# 4                   0.33                          387.00                 NaN
# 5                   8.36                       10,296.00                 NaN
# 6                   8.99                        8,841.00                 NaN
# 7                   6.12                        5,232.00                 NaN
# 8                   0.58                          681.00                 NaN
# 9                   0.56                          657.00                 NaN
#
#   affordable_solar community_distributed_generation  \
# 0               No                               No
# 1               No                               No
# 2               No                               No
# 3               No                               No
# 4               No                               No
# 5               No                               No
# 6               No                               No
# 7               No                               No
# 8               No                               No
# 9               No                               No
#
#   green_jobs_green_new_york_participant                  georeference
# 0                                    No  POINT (-73.864226 41.011999)
# 1                                    No   POINT (-74.01954 41.336299)
# 2                                    No  POINT (-71.949914 41.042541)
# 3                                    No  POINT (-73.882182 41.217937)
# 4                                    No  POINT (-72.872417 40.794939)
# 5                                   Yes  POINT (-73.899203 40.846788)
# 6                                    No     POINT (-73.7738 40.76347)
# 7                                    No  POINT (-79.325071 42.090549)
# 8                                    No  POINT (-73.686254 40.793129)
# 9                                    No   POINT (-72.34152 40.925685)

# %%
df.head(3).T
# Out:
#                                                                   0  \
# reporting_period                                2021-11-30 00:00:00
# project_number                                           0000002557
# legacy_project_number                                        2035-1
# city                                                    Dobbs Ferry
# county                                                          NaN
# state                                                            NY
# zip_code                                                      10522
# sector                                              Non-Residential
# program_type                           Residential/Small Commercial
# solicitation                                          ARRA Projects
# electric_utility                                Consolidated Edison
# purchase_type                                                   NaN
# date_application_received                       2011-12-15 00:00:00
# date_completed                                  2011-12-15 00:00:00
# project_status                                             Complete
# contractor                                                      NaN
# primary_inverter_manufacturer                            PV Powered
# primary_inverter_model_number                           PVP50KW-208
# total_inverter_quantity                                        1.00
# primary_pv_module_manufacturer                                Sharp
# pv_module_model_number                                    NU-U240F1
# total_pv_module_quantity                                     204.00
# project_cost                                                   0.00
# incentive                                                       NaN
# total_nameplate_kw_dc                                         48.96
# expected_kwh_annual_production                            52,433.00
# remote_net_metering                                             NaN
# affordable_solar                                                 No
# community_distributed_generation                                 No
# green_jobs_green_new_york_participant                            No
# georeference                           POINT (-73.864226 41.011999)
#
#                                                                   1  \
# reporting_period                                2021-11-30 00:00:00
# project_number                                           0000000275
# legacy_project_number                                   01001-00017
# city                                                 Highland Falls
# county                                                       Orange
# state                                                            NY
# zip_code                                                      10928
# sector                                              Non-Residential
# program_type                           Residential/Small Commercial
# solicitation                                               PON 1184
# electric_utility                                                NaN
# purchase_type                                                   NaN
# date_application_received                       2003-08-02 00:00:00
# date_completed                                  2005-05-24 00:00:00
# project_status                                             Complete
# contractor                                        Solar Works, Inc.
# primary_inverter_manufacturer                           Fronius USA
# primary_inverter_model_number                            IG 2500-LV
# total_inverter_quantity                                        1.00
# primary_pv_module_manufacturer                             BP Solar
# pv_module_model_number                                      BP3125S
# total_pv_module_quantity                                      16.00
# project_cost                                                   0.00
# incentive                                                       NaN
# total_nameplate_kw_dc                                          2.00
# expected_kwh_annual_production                                  NaN
# remote_net_metering                                             NaN
# affordable_solar                                                 No
# community_distributed_generation                                 No
# green_jobs_green_new_york_participant                            No
# georeference                            POINT (-74.01954 41.336299)
#
#                                                                   2
# reporting_period                                2021-11-30 00:00:00
# project_number                                     2011-158775-SLPR
# legacy_project_number                                           NaN
# city                                                        Montauk
# county                                                      Suffolk
# state                                                            NY
# zip_code                                                      11954
# sector                                                  Residential
# program_type                           Residential/Small Commercial
# solicitation                                  SLPR 2010 Residential
# electric_utility                        Long Island Power Authority
# purchase_type                                              Purchase
# date_application_received                       2008-10-01 00:00:00
# date_completed                                  2008-10-01 00:00:00
# project_status                                             Complete
# contractor                                                      NaN
# primary_inverter_manufacturer                                   NaN
# primary_inverter_model_number                                   NaN
# total_inverter_quantity                                        0.00
# primary_pv_module_manufacturer                                  NaN
# pv_module_model_number                                          NaN
# total_pv_module_quantity                                       0.00
# project_cost                                              34,109.00
# incentive                                                  1,020.00
# total_nameplate_kw_dc                                          0.27
# expected_kwh_annual_production                               317.00
# remote_net_metering                                             NaN
# affordable_solar                                                 No
# community_distributed_generation                                 No
# green_jobs_green_new_york_participant                            No
# georeference                           POINT (-71.949914 41.042541)

# %%
df['electric_utility'].value_counts(dropna=False)
# Out:
# Consolidated Edison                42073
# Long Island Power Authority        30446
# National Grid                      21411
# Central Hudson Gas and Electric    11058
# Orange and Rockland Utilities       9464
# NYS Electric and Gas                9461
# Rochester Gas and Electric          2132
# NaN                                   44
# Statewide                              1
# Name: electric_utility, dtype: int64

# %%
def assignments(x):
    return {
        'Consolidated Edison': 'CONED',
        'National Grid': 'NATGRID',
        'Long Island Power Authority': 'LIPA',
        'Orange and Rockland Utilities':'ORU',
    }.get(x, 'Other')

# %%
df['utility'] = df['electric_utility'].apply(assignments)
df['utility'].value_counts()
# Out:
# CONED      42073
# LIPA       30446
# Other      22696
# NATGRID    21411
# ORU         9464
# Name: utility, dtype: int64

# %%
df.filter(regex='date').isna().sum()
# Out:
# date_application_received       0
# date_completed               6454
# dtype: int64

# %%
df['application_year'] = df['date_application_received'].dt.year
df['application_month'] = df['date_application_received'].dt.month

# %%
pivot = df.pivot_table(
    index='application_year',
    columns='application_month',
    values='project_cost',
    aggfunc=np.sum,
    fill_value=0
)
pivot
# Out:
# application_month             1              2              3              4   \
# application_year
# 2000                        0.00           0.00           0.00           0.00
# 2001                        0.00           0.00      50,392.30           0.00
# 2002                  124,724.80      24,600.00     100,100.00     146,244.00
# 2003                  302,811.70     698,680.80     558,988.80     737,936.90
# 2004                  896,064.64     591,482.40   1,321,812.40   1,300,223.72
# 2005                1,000,964.66     796,774.38   1,093,962.15     595,059.31
# 2006                1,078,579.99     960,439.72   1,552,375.54   1,574,722.86
# 2007                2,399,429.42   5,103,550.11   4,284,351.88   2,430,726.51
# 2008                2,802,804.87   5,858,537.66   4,519,417.56   3,536,101.88
# 2009               23,790,188.59  19,014,425.35   5,305,686.66   5,042,359.90
# 2010               14,792,196.73  12,318,451.06  11,864,190.00  15,231,626.51
# 2011                5,886,306.95  13,063,652.60   7,212,163.25  10,194,176.82
# 2012               14,944,691.91  20,915,042.50  13,020,222.14   8,749,915.36
# 2013               19,728,018.27  50,130,484.20  21,263,753.06  19,967,272.25
# 2014               79,360,207.14  17,347,905.10  31,630,945.70  63,389,598.66
# 2015               57,299,039.95 109,196,493.48  57,889,326.49  59,569,960.23
# 2016              101,182,545.90 108,720,126.98 123,410,774.22  88,259,144.97
# 2017               95,285,567.39 110,557,411.52 229,268,296.93  77,986,902.44
# 2018               45,127,450.04  42,384,468.30  33,777,914.07  48,349,886.90
# 2019               93,880,756.21 165,701,098.90 119,029,387.20  36,993,455.23
# 2020              128,384,461.01 117,393,396.41 147,725,553.67 225,697,811.89
# 2021              201,205,513.15 198,154,828.97 194,238,825.34 182,476,406.38
#
# application_month             5              6              7              8   \
# application_year
# 2000                        0.00           0.00           0.00           0.00
# 2001                        0.00           0.00      23,219.00      52,780.00
# 2002                  407,437.00     332,530.30     650,757.40   1,137,747.50
# 2003                  324,878.90     975,440.50     551,499.00     882,536.80
# 2004                  971,496.70   1,059,198.66     787,119.01     392,641.15
# 2005                1,287,436.02     758,224.01   1,218,596.02   1,699,074.69
# 2006                1,749,526.19   2,267,930.26   3,079,182.26   2,139,510.85
# 2007                2,982,939.06   3,497,697.11   3,786,062.33   4,037,162.55
# 2008                3,136,864.87   4,420,160.99   5,980,871.59  11,755,064.69
# 2009                6,126,814.14   3,712,409.51   5,384,367.91  10,236,351.29
# 2010               21,909,528.55  44,901,238.11  11,863,216.64  11,443,426.29
# 2011               10,489,020.99  13,198,744.35  36,893,494.59  12,641,400.09
# 2012               28,949,059.83  12,981,519.41  30,657,527.14  14,388,651.55
# 2013               36,015,964.63  54,717,050.03  32,410,639.24  50,724,312.57
# 2014               58,465,849.15  69,140,542.78  68,902,462.47  55,611,710.03
# 2015               80,339,070.34 104,782,786.62  80,817,330.22  79,890,274.78
# 2016              182,193,942.76 102,688,108.06  70,317,332.50  71,268,701.85
# 2017               64,180,069.90  25,765,205.65 138,212,161.03 120,469,735.06
# 2018               48,158,958.57  71,921,282.44  43,427,323.95  32,637,329.09
# 2019               76,203,036.73  93,401,609.13  64,866,035.70 128,818,577.17
# 2020              132,801,758.43  75,599,437.71 137,772,276.14 131,909,998.04
# 2021              252,561,806.14 136,355,836.36  75,262,055.70  68,055,434.39
#
# application_month             9              10             11             12
# application_year
# 2000                        0.00           0.00           0.00      21,133.20
# 2001                   22,400.00      80,442.40      26,200.00           0.00
# 2002                  720,107.60   1,627,281.70     678,943.40     710,226.70
# 2003                  870,984.20   1,154,654.80     790,476.50     655,042.00
# 2004                  588,360.48   1,319,089.18     475,491.00     470,086.46
# 2005                  860,058.52   1,720,188.01   1,027,907.80   1,270,307.33
# 2006                2,270,803.33   4,520,091.40   2,556,375.24   2,762,505.52
# 2007                2,857,374.08   3,470,222.55   4,638,970.97   2,477,145.98
# 2008                9,591,594.52  10,490,538.05   4,978,445.83  10,325,452.53
# 2009               14,040,086.38  14,879,418.89  12,770,554.95  14,868,048.98
# 2010               15,363,753.21  15,706,367.10  18,908,102.03   7,382,879.54
# 2011               21,875,433.77  21,879,033.69  21,089,628.08  21,434,594.79
# 2012               15,794,989.80  16,731,569.90  11,099,195.04  12,812,524.00
# 2013               40,348,002.46  52,005,529.14  33,733,634.60  71,628,601.42
# 2014               76,419,700.07 190,458,550.60  63,155,858.92  97,227,136.27
# 2015               51,152,382.87 115,908,172.30  97,031,008.99 122,997,637.26
# 2016               58,890,074.36  37,019,875.87  70,755,351.93  94,725,862.51
# 2017               58,544,863.26  49,021,190.39  49,570,895.13  42,087,572.90
# 2018               49,092,281.24  65,218,100.95  50,412,444.35  71,709,990.67
# 2019               95,872,781.98 179,229,936.22 109,570,971.31 165,000,583.28
# 2020              176,950,045.23 179,135,882.38 280,251,702.72 179,206,053.28
# 2021              192,202,544.82  54,384,092.55  60,054,391.53           0.00

# %%
idx = 'application_year'

df[[idx, 'project_cost', 'incentive']]\
.groupby(idx).sum()\
.plot.bar(stacked=True, figsize=(14,6), width=.75, rot=0);

# %%
df.dropna(subset=['date_completed'], inplace=True)
df['date_application_received'] = df['date_application_received'].astype(str).apply(lambda x: x[0:10])
df['date_completed'] = df['date_completed'].astype(str).apply(lambda x: x[0:10])

# %%
business_days = []

for row in df.itertuples():
    business_days.append(np.busday_count(row.date_application_received,row.date_completed))
    
df['business_days'] = business_days

df.head()
# Out:
#   reporting_period    project_number legacy_project_number            city  \
# 0       2021-11-30        0000002557                2035-1     Dobbs Ferry
# 1       2021-11-30        0000000275           01001-00017  Highland Falls
# 2       2021-11-30  2011-158775-SLPR                   NaN         Montauk
# 4       2021-11-30  2011-156499-SLPR                   NaN         Shirley
# 6       2021-11-30        0000234406                   NaN          Queens
#
#     county state  zip_code           sector                  program_type  \
# 0      NaN    NY     10522  Non-Residential  Residential/Small Commercial
# 1   Orange    NY     10928  Non-Residential  Residential/Small Commercial
# 2  Suffolk    NY     11954      Residential  Residential/Small Commercial
# 4  Suffolk    NY     11967      Residential  Residential/Small Commercial
# 6   Queens    NY     11361      Residential  Residential/Small Commercial
#
#             solicitation             electric_utility purchase_type  \
# 0          ARRA Projects          Consolidated Edison           NaN
# 1               PON 1184                          NaN           NaN
# 2  SLPR 2010 Residential  Long Island Power Authority      Purchase
# 4  SLPR 2010 Residential  Long Island Power Authority      Purchase
# 6               PON 2112          Consolidated Edison         Lease
#
#   date_application_received date_completed project_status         contractor  \
# 0                2011-12-15     2011-12-15       Complete                NaN
# 1                2003-08-02     2005-05-24       Complete  Solar Works, Inc.
# 2                2008-10-01     2008-10-01       Complete                NaN
# 4                2002-11-18     2002-11-18       Complete                NaN
# 6                2020-02-15     2020-03-24       Complete        SunRun Inc.
#
#   primary_inverter_manufacturer primary_inverter_model_number  \
# 0                    PV Powered                   PVP50KW-208
# 1                   Fronius USA                    IG 2500-LV
# 2                           NaN                           NaN
# 4                           NaN                           NaN
# 6             Delta Electronics               M4-TL-US [240V]
#
#    total_inverter_quantity primary_pv_module_manufacturer  \
# 0                     1.00                          Sharp
# 1                     1.00                       BP Solar
# 2                     0.00                            NaN
# 4                     0.00                            NaN
# 6                     2.00                      REC Solar
#
#   pv_module_model_number  total_pv_module_quantity  project_cost  incentive  \
# 0              NU-U240F1                    204.00          0.00        nan
# 1                BP3125S                     16.00          0.00        nan
# 2                    NaN                      0.00     34,109.00   1,020.00
# 4                    NaN                      0.00      2,455.00   1,650.00
# 6             REC310TP2M                     29.00     19,706.00   1,798.00
#
#    total_nameplate_kw_dc  expected_kwh_annual_production remote_net_metering  \
# 0                  48.96                       52,433.00                 NaN
# 1                   2.00                             nan                 NaN
# 2                   0.27                          317.00                 NaN
# 4                   0.33                          387.00                 NaN
# 6                   8.99                        8,841.00                 NaN
#
#   affordable_solar community_distributed_generation  \
# 0               No                               No
# 1               No                               No
# 2               No                               No
# 4               No                               No
# 6               No                               No
#
#   green_jobs_green_new_york_participant                  georeference utility  \
# 0                                    No  POINT (-73.864226 41.011999)   CONED
# 1                                    No   POINT (-74.01954 41.336299)   Other
# 2                                    No  POINT (-71.949914 41.042541)    LIPA
# 4                                    No  POINT (-72.872417 40.794939)    LIPA
# 6                                    No     POINT (-73.7738 40.76347)   CONED
#
#    application_year  application_month  business_days
# 0              2011                 12              0
# 1              2003                  8            471
# 2              2008                 10              0
# 4              2002                 11              0
# 6              2020                  2             26

# %%
sns.displot(df['business_days']);

# %%
g = sns.FacetGrid(data=df, col="utility",)
g = g.map(sns.histplot, "business_days")

# %%
sns.boxenplot(data=df, x='utility', y='business_days', color='red');

# %%
df.query("business_days < 0")
# Out:
#        reporting_period    project_number legacy_project_number  \
# 46512        2021-11-30  2011-160497-SLPR                   NaN
# 56701        2021-11-30        0000038224            4944-90776
# 70305        2021-11-30        0000057315            5098-95936
# 72443        2021-11-30        0000054955            5297-90774
# 86803        2021-11-30  2012-457120-SLPR                   NaN
# ...                 ...               ...                   ...
# 125680       2021-11-30  2011-160697-SLPR                   NaN
# 125807       2021-11-30          31328A-1                   NaN
# 125899       2021-11-30          49761A-1                   NaN
# 126006       2021-11-30  2012-457099-SLPR                   NaN
# 126036       2021-11-30          49803A-1                   NaN
#
#                  city       county state  zip_code           sector  \
# 46512         Shirley      Suffolk    NY     11967      Residential
# 56701        Ossining  Westchester    NY     10562      Residential
# 70305       Tonawanda         Erie    NY     14150      Residential
# 72443     Rock Tavern       Orange    NY     12575      Residential
# 86803        Bayville       Nassau    NY     11709      Residential
# ...               ...          ...   ...       ...              ...
# 125680  East Moriches      Suffolk    NY     11940  Non-Residential
# 125807     Orangeburg     Rockland    NY     10962  Non-Residential
# 125899      Greenwich   Washington    NY     12834  Non-Residential
# 126006      Brentwood      Suffolk    NY     11717  Non-Residential
# 126036       Walworth        Wayne    NY     14568  Non-Residential
#
#                                program_type               solicitation  \
# 46512          Residential/Small Commercial              Solar Pioneer
# 56701          Residential/Small Commercial                   PON 2112
# 70305          Residential/Small Commercial                   PON 2112
# 72443          Residential/Small Commercial                   PON 2112
# 86803          Residential/Small Commercial      SLPR 2010 Residential
# ...                                     ...                        ...
# 125680         Residential/Small Commercial         Solar Entreprenuer
# 125807  Commercial/Industrial (Competitive)                  PON 2589B
# 125899  Commercial/Industrial (Competitive)                   PON 2956
# 126006         Residential/Small Commercial  SLPR ENTRPNR 2010 Schools
# 126036  Commercial/Industrial (Competitive)                   PON 2956
#
#                        electric_utility             purchase_type  \
# 46512       Long Island Power Authority                  Purchase
# 56701               Consolidated Edison                     Lease
# 70305                     National Grid                     Lease
# 72443   Central Hudson Gas and Electric                     Lease
# 86803       Long Island Power Authority                  Purchase
# ...                                 ...                       ...
# 125680      Long Island Power Authority                  Purchase
# 125807    Orange and Rockland Utilities                  Purchase
# 125899                    National Grid  Power Purchase Agreement
# 126006      Long Island Power Authority                  Purchase
# 126036       Rochester Gas and Electric  Power Purchase Agreement
#
#        date_application_received date_completed project_status  \
# 46512                 2011-02-16     2011-01-25       Complete
# 56701                 2016-02-18     2015-12-31       Complete
# 70305                 2016-04-14     2016-01-13       Complete
# 72443                 2016-02-18     2015-10-26       Complete
# 86803                 2012-02-07     2011-02-24       Complete
# ...                          ...            ...            ...
# 125680                2011-02-16     2011-01-25       Complete
# 125807                2014-06-05     2013-12-31       Complete
# 125899                2016-04-25     2016-04-04       Complete
# 126006                2012-02-07     2011-03-23       Complete
# 126036                2016-06-17     2016-06-08       Complete
#
#                              contractor  \
# 46512                               NaN
# 56701                       SunRun Inc.
# 70305   NRG Residential Solar Solutions
# 72443              SunPower Capital LLC
# 86803                               NaN
# ...                                 ...
# 125680                              NaN
# 125807                Picker Properties
# 125899         WGL Energy Systems, Inc.
# 126006                              NaN
# 126036         WGL Energy Systems, Inc.
#
#                   primary_inverter_manufacturer  \
# 46512                                 Solectria
# 56701                    SolarEdge Technologies
# 70305                            Enphase Energy
# 72443                               SMA America
# 86803                                       NaN
# ...                                         ...
# 125680                              SMA America
# 125807  Advanced Energy Industries AE 500TX-480
# 125899                                      NaN
# 126006                                      NaN
# 126036                                      NaN
#
#              primary_inverter_model_number  total_inverter_quantity  \
# 46512                                  NaN                     1.00
# 56701      SE5000 (240V) w/ -ER-US or A-US                     1.00
# 70305   M250-60-2LL-S2X (-ZC) (-NA) (240V)                    20.00
# 72443         SB6000TL-US-22 (240V) (240V)                     1.00
# 86803                                  NaN                     1.00
# ...                                    ...                      ...
# 125680                                 NaN                     1.00
# 125807                                 NaN                     0.00
# 125899                                 NaN                      nan
# 126006                                 NaN                     1.00
# 126036                                 NaN                      nan
#
#             primary_pv_module_manufacturer pv_module_model_number  \
# 46512                                Sharp                    NaN
# 56701                            REC Solar          REC260PE(BLK)
# 70305   LG Electronics Solar Cell Division            LG275S1C-B3
# 72443                             SunPower            SPR-E20-327
# 86803                               SCHUCO                    NaN
# ...                                    ...                    ...
# 125680                               Solon                    NaN
# 125807            Canadian Solar CS6P-250P                    NaN
# 125899                                 NaN                    NaN
# 126006                          GENERAL EL                    NaN
# 126036                                 NaN                    NaN
#
#         total_pv_module_quantity  project_cost    incentive  \
# 46512                      22.00     22,660.00    11,330.00
# 56701                      22.00     15,857.00     2,482.00
# 70305                      20.00     16,498.85     3,300.00
# 72443                      20.00     29,980.10     3,924.00
# 86803                      38.00     27,836.00     5,110.00
# ...                          ...           ...          ...
# 125680                     40.00     82,800.00    41,400.00
# 125807                      0.00  2,260,375.00   518,891.10
# 125899                       nan  4,701,880.00 1,290,163.46
# 126006                     36.00     70,200.00    32,400.00
# 126036                       nan  3,280,200.00   404,750.14
#
#         total_nameplate_kw_dc  expected_kwh_annual_production  \
# 46512                    4.36                        5,113.00
# 56701                    5.72                        6,216.00
# 70305                    5.50                        5,934.00
# 72443                    6.54                        8,165.00
# 86803                    6.84                        8,029.00
# ...                       ...                             ...
# 125680                   9.20                       10,799.00
# 125807                 854.75                      823,637.00
# 125899               2,604.62                    3,057,407.00
# 126006                   7.20                        8,452.00
# 126036               1,566.74                    1,839,102.00
#
#        remote_net_metering affordable_solar community_distributed_generation  \
# 46512                  NaN               No                               No
# 56701                   No               No                               No
# 70305                   No               No                               No
# 72443                   No               No                               No
# 86803                  NaN               No                               No
# ...                    ...              ...                              ...
# 125680                 NaN               No                               No
# 125807                 NaN               No                               No
# 125899                 NaN               No                               No
# 126006                 NaN               No                               No
# 126036                 NaN               No                               No
#
#        green_jobs_green_new_york_participant                  georeference  \
# 46512                                     No  POINT (-72.872417 40.794939)
# 56701                                     No  POINT (-73.841562 41.182134)
# 70305                                     No  POINT (-78.867291 42.999597)
# 72443                                     No  POINT (-74.151998 41.484556)
# 86803                                     No  POINT (-73.560422 40.907457)
# ...                                      ...                           ...
# 125680                                    No  POINT (-72.755576 40.810652)
# 125807                                    No  POINT (-73.961988 41.046226)
# 125899                                    No  POINT (-73.500001 43.097845)
# 126006                                    No   POINT (-73.247736 40.78528)
# 126036                                    No  POINT (-77.283425 43.141672)
#
#         utility  application_year  application_month  business_days
# 46512      LIPA              2011                  2            -16
# 56701     CONED              2016                  2            -35
# 70305   NATGRID              2016                  4            -66
# 72443     Other              2016                  2            -83
# 86803      LIPA              2012                  2           -248
# ...         ...               ...                ...            ...
# 125680     LIPA              2011                  2            -16
# 125807      ORU              2014                  6           -112
# 125899  NATGRID              2016                  4            -15
# 126006     LIPA              2012                  2           -229
# 126036    Other              2016                  6             -7
#
# [166 rows x 35 columns]

# %%
df['business_days'].describe()
# Out:
# count   119,636.00
# mean        107.74
# std         105.42
# min        -759.00
# 25%          43.00
# 50%          80.00
# 75%         138.00
# max       2,688.00
# Name: business_days, dtype: float64

# %%
cut_days = pd.cut(df['business_days'], [-1000,0,10,20,30,60,90,360,3000])

df.pivot_table(index=cut_days, columns='utility', values='project_cost', aggfunc=np.sum, fill_value=0)
# Out:
# utility                CONED           LIPA        NATGRID            ORU  \
# business_days
# (-1000, 0]     27,491,353.84 189,057,249.87  29,046,922.65  10,982,182.00
# (0, 10]        21,404,943.59   1,290,563.51  14,437,264.32   6,731,995.73
# (10, 20]       62,803,984.50   7,020,640.19  34,267,714.11  23,465,072.45
# (20, 30]       98,840,459.90  17,268,600.28  57,473,547.98  25,413,248.97
# (30, 60]      268,645,604.10 119,252,031.89 219,067,802.39  90,488,652.61
# (60, 90]      193,661,816.69 165,384,647.84 181,184,753.11  67,387,282.38
# (90, 360]     696,694,358.52 701,223,206.85 548,529,797.68 140,865,784.29
# (360, 3000]   253,995,352.47  82,481,373.54 869,614,079.56 126,818,192.12
#
# utility                Other
# business_days
# (-1000, 0]     30,729,830.70
# (0, 10]        15,562,111.69
# (10, 20]       35,021,083.12
# (20, 30]       51,093,732.87
# (30, 60]      191,323,637.44
# (60, 90]      177,586,580.46
# (90, 360]     559,650,507.20
# (360, 3000]   815,363,520.94

# %%
df.groupby('project_number')[['project_cost', 'expected_kwh_annual_production']].sum().corr()
# Out:
#                                 project_cost  expected_kwh_annual_production
# project_cost                            1.00                            0.94
# expected_kwh_annual_production          0.94                            1.00

# %%
ax = sns.regplot(x=df['project_cost'], y=df['expected_kwh_annual_production'], color="b", dropna=True);

# %%
# Show the results of a linear regression within each dataset
sns.lmplot(
    x='project_cost',
    y='expected_kwh_annual_production',
    col='utility',
    hue='sector',
    col_wrap=3,
    ci=None,
    palette='muted',
    height=4,
    scatter_kws={'s': 50, 'alpha': .4},
    data=df.query("application_year == 2019"),
);

# %%
df['utility'].unique()
# Out:
# array(['CONED', 'Other', 'LIPA', 'ORU', 'NATGRID'], dtype=object)

# %%
for utility in df['utility'].unique():
    df.query(f"utility == '{utility}'").to_csv(f"solar_df_{utility}.csv", index=None)

# %%
glob.glob('solar_df*.csv')
# Out:
# ['solar_df_CONED.csv',
#  'solar_df_Other.csv',
#  'solar_df_ORU.csv',
#  'solar_df_LIPA.csv',
#  'solar_df_NATGRID.csv']

# %%
counties = df.county.value_counts(dropna=False).reset_index()
counties.rename(columns = {'index':'county', 'county':'total'}, inplace=True)
counties
# Out:
#           county  total
# 0        Suffolk  18723
# 1         Queens  12220
# 2         Nassau  10937
# 3       Richmond   8788
# 4    Westchester   7913
# 5         Orange   6920
# 6          Kings   6104
# 7       Dutchess   4060
# 8       Rockland   3866
# 9         Ulster   3633
# 10          Erie   3090
# 11        Albany   3024
# 12         Bronx   2740
# 13      Saratoga   2349
# 14    Rensselaer   2110
# 15   Schenectady   1940
# 16        Monroe   1573
# 17      Tompkins   1545
# 18      Onondaga   1290
# 19      New York   1183
# 20      Columbia   1112
# 21        Greene    729
# 22        Oneida    727
# 23    Montgomery    717
# 24       Niagara    672
# 25    Washington    671
# 26        Putnam    663
# 27        Warren    636
# 28      Sullivan    617
# 29       Ontario    573
# 30  St. Lawrence    538
# 31        Oswego    440
# 32        Broome    418
# 33        Fulton    407
# 34     Schoharie    390
# 35    Chautauqua    388
# 36         Wayne    384
# 37           NaN    366
# 38       Madison    355
# 39     Jefferson    351
# 40        Cayuga    344
# 41         Essex    308
# 42        Otsego    305
# 43    Livingston    295
# 44      Cortland    256
# 45         Tioga    247
# 46       Clinton    246
# 47       Genesee    227
# 48   Cattaraugus    207
# 49      Herkimer    201
# 50       Chemung    195
# 51       Orleans    193
# 52      Delaware    187
# 53      Franklin    166
# 54      Schuyler    157
# 55      Chenango    152
# 56       Wyoming    149
# 57        Seneca    149
# 58       Steuben    142
# 59         Yates    139
# 60      Allegany    118
# 61         Lewis     56
# 62      Hamilton     35

# %%
filename = 'https://data.ny.gov/api/views/4xc7-bukh/rows.csv?accessType=DOWNLOAD&sorting=true'

cs = pd.read_csv(filename)
cs.columns = cs.columns.str.replace(' ','-').str.lower()
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   county          63 non-null     object
#  1   county-seat     63 non-null     object
#  2   address         63 non-null     object
#  3   city            63 non-null     object
#  4   zip5            63 non-null     int64
#  5   contact-type    63 non-null     object
#  6   phone           63 non-null     object
#  7   longitude       63 non-null     float64
#  8   latitude        63 non-null     float64
#  9   county-website  63 non-null     object
#  10  location        63 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 5.5+ KB

# %%
counties = pd.merge(left=counties, right=cs, how='inner')
counties
# Out:
#          county  total               county-seat  \
# 0       Suffolk  18723         Town of Riverhead
# 1        Queens  12220         Borough of Queens
# 2        Nassau  10937        Village of Mineola
# 3      Richmond   8788  Borough of Staten Island
# 4   Westchester   7913      City of White Plains
# 5        Orange   6920         Village of Goshen
# 6         Kings   6104       Borough of Brooklyn
# 7      Dutchess   4060      City of Poughkeepsie
# 8      Rockland   3866        Hamlet of New City
# 9        Ulster   3633          City of Kingston
# 10         Erie   3090           City of Buffalo
# 11       Albany   3024            City of Albany
# 12        Bronx   2740      Borough of the Bronx
# 13     Saratoga   2349   Village of Ballston Spa
# 14   Rensselaer   2110              City of Troy
# 15  Schenectady   1940       City of Schenectady
# 16       Monroe   1573         City of Rochester
# 17     Tompkins   1545            City of Ithaca
# 18     Onondaga   1290          City of Syracuse
# 19     New York   1183      Borough of Manhattan
# 20     Columbia   1112            City of Hudson
# 21       Greene    729       Village of Catskill
# 22       Oneida    727             City of Utica
# 23   Montgomery    717          Village of Fonda
# 24      Niagara    672          City of Lockport
# 25   Washington    671       Town of Fort Edward
# 26       Putnam    663            Town of Carmel
# 27       Warren    636        Town of Queensbury
# 28     Sullivan    617     Village of Monticello
# 29      Ontario    573       City of Canandaigua
# 30       Oswego    440            City of Oswego
# 31       Broome    418        City of Binghamton
# 32       Fulton    407         City of Johnstown
# 33    Schoharie    390      Village of Schoharie
# 34   Chautauqua    388       Village of Mayville
# 35        Wayne    384          Village of Lyons
# 36      Madison    355     Village of Wampsville
# 37    Jefferson    351         City of Watertown
# 38       Cayuga    344            City of Auburn
# 39        Essex    308   Hamlet of Elizabethtown
# 40       Otsego    305    Village of Cooperstown
# 41   Livingston    295        Village of Geneseo
# 42     Cortland    256          City of Cortland
# 43        Tioga    247          Village of Owego
# 44      Clinton    246       City of Plattsburgh
# 45      Genesee    227           City of Batavia
# 46  Cattaraugus    207  Village of Little Valley
# 47     Herkimer    201       Village of Herkimer
# 48      Chemung    195            City of Elmira
# 49      Orleans    193         Village of Albion
# 50     Delaware    187          Village of Delhi
# 51     Franklin    166         Village of Malone
# 52     Schuyler    157   Village of Watkins Glen
# 53     Chenango    152           City of Norwich
# 54      Wyoming    149         Village of Warsaw
# 55       Seneca    149       Village of Waterloo
# 56      Steuben    142           Village of Bath
# 57        Yates    139       Village of Penn Yan
# 58     Allegany    118        Village of Belmont
# 59        Lewis     56       Village of Lowville
# 60     Hamilton     35   Hamlet of Lake Pleasant
#
#                          address           city   zip5  \
# 0                 300 Center Dr.      Riverhead  11901
# 1        120-55 Queens Boulevard       New York  11424
# 2             1550 Franklin Ave.        Mineola  11501
# 3            10 Richmond Terrace       New York  10301
# 4               148 Martine Ave.   White Plains  10601
# 5                255 Main Street         Goshen  10924
# 6               209 Joralemon St       New York  11201
# 7       22 Market St., 6Th Floor   Poughkeepsie  12601
# 8           11 New Hempstead Rd.       New City  10956
# 9                244 Fair Street       Kingston  12402
# 10               95 Franklin St.        Buffalo  14202
# 11              112 State Street         Albany  12207
# 12           851 Grand Concourse       New York  10451
# 13               40 McMaster St.   Ballston Spa  12020
# 14               1600 7Th Avenue           Troy  12180
# 15                 620 State St.    Schenectady  12305
# 16                39 W. Main St.      Rochester  14614
# 17              320 N. Tioga St.         Ithaca  14850
# 18            421 Montgomery St.       Syracuse  13202
# 19                   1 Centre St       New York  10007
# 20                 401 State St.         Hudson  12534
# 21                  411 Main St.       Catskill  12414
# 22                 800 Park Ave.          Utica  13501
# 23                   64 Broadway          Fonda  12068
# 24                175 Hawley St.       Lockport  14094
# 25                  383 Broadway    Fort Edward  12828
# 26              40 Gleneida Ave.         Carmel  10512
# 27            1340 State Route 9    Lake George  12845
# 28              100 North Street     Monticello  12701
# 29                20 Ontario St.    Canandaigua  14424
# 30              46 E. Bridge St.         Oswego  13126
# 31              60 Hawley Street     Binghamton  13902
# 32               223 W. Main St.      Johnstown  12095
# 33                  284 Main St.      Schoharie  12157
# 34           3 North Erie Street       Mayville  14757
# 35                 26 Church St.          Lyons  14489
# 36               138 N. Court St     Wampsville  13163
# 37               195 Arsenal St.      Watertown  13601
# 38               160 Genesee St.         Auburn  13021
# 39  7551 Court St., P.O. Box 217  Elizabethtown  12932
# 40                  197 Main St.    Cooperstown  13326
# 41                   6 Court St.        Geneseo  14454
# 42               60 Central Ave.       Cortland  13045
# 43                   56 Main St.          Owego  13827
# 44              137 Margaret St.    Plattsburgh  12901
# 45                    7 Main St.        Batavia  14020
# 46                 303 Court St.  Little Valley  14755
# 47      109 Mary St., Suite 1310       Herkimer  13350
# 48                  203 Lake St.         Elmira  14902
# 49        3 S. Main St., Suite 2         Albion  14411
# 50                  111 Main St.          Delhi  13753
# 51               355 W. Main St.         Malone  12953
# 52                 105 Ninth St.   Watkins Glen  14891
# 53                   5 Court St.        Norwich  13815
# 54               143 N. Main St.         Warsaw  14569
# 55                1 DiPronio Dr.       Waterloo  13165
# 56          3 E. Pulteney Square           Bath  14810
# 57               417 Liberty St.       Penn Yan  14527
# 58                   7 Court St.        Belmont  14813
# 59                7660 State St.       Lowville  13367
# 60         102 County View Drive  Lake Pleasant  12108
#
#                              contact-type          phone  longitude  latitude  \
# 0               County Executive's Office  (631)852-1700     -72.67     40.91
# 1              Borough President's Office  (718)286-3000     -73.83     40.71
# 2               County Executive's Office  (516)571-3000     -73.64     40.74
# 3              Borough President's Office  (718)816-2000     -74.08     40.64
# 4               County Executive's Office  (914)995-2000     -73.77     41.03
# 5               County Executive's Office  (845)291-3000     -74.32     41.41
# 6              Borough President's Office  (718)802-3700     -73.99     40.69
# 7               County Executive's Office  (845)486-2100     -73.93     41.70
# 8               County Executive's Office  (845)638-5100     -73.99     41.15
# 9               County Executive's Office  (845)340-3800     -74.02     41.93
# 10              County Executive's Office  (716)858-7450     -78.88     42.88
# 11              County Executive's Office  (518)447-7040     -73.75     42.65
# 12             Borough President's Office  (718)590-3500     -73.92     40.83
# 13          County Administrator's Office  (518)884-4742     -73.85     43.00
# 14              County Executive's Office  (518)270-2900     -73.69     42.73
# 15                County Manager's Office  (518)388-4280     -73.94     42.81
# 16              County Executive's Office  (585)753-1000     -77.61     43.16
# 17          County Administrator's Office  (607)274-5434     -76.50     42.44
# 18              County Executive's Office  (315)435-2222     -76.15     43.05
# 19             Borough President's Office  (212)669-8300     -74.00     40.71
# 20                  County Clerk's Office  (518)828-3339     -73.79     42.25
# 21          County Administrator's Office  (518)719-3270     -73.87     42.22
# 22              County Executive's Office  (315)798-5700     -75.23     43.10
# 23                  County Clerk's Office  (518)853-8111     -74.38     42.96
# 24                County Manager's Office  (716)439-7213     -78.70     43.17
# 25          County Administrator's Office  (518)746-2590     -73.59     43.29
# 26              County Executive's Office  (845)808-1000     -73.68     41.43
# 27          County Administrator's Office  (518)761-6539     -73.70     43.36
# 28                County Manager's Office  (845)794-3000     -74.69     41.66
# 29          County Administrator's Office  (585)396-4400     -77.28     42.89
# 30          County Administrator's Office  (315)349-8235     -76.51     43.46
# 31              County Executive's Office  (607)778-2109     -75.91     42.10
# 32                  County Clerk's Office  (518)736-5555     -74.38     43.01
# 33                  County Clerk's Office  (518)295-8316     -74.31     42.66
# 34              County Executive's Office  (716)753-7111     -79.50     42.25
# 35          County Administrator's Office  (315)946-5480     -76.99     43.06
# 36                  County Clerk's Office  (315)366-2261     -75.71     43.08
# 37          County Administrator's Office  (315)785-3075     -75.91     43.98
# 38          County Administrator's Office  (315)253-1525     -76.57     42.93
# 39                County Manager's Office  (518)873-3333     -73.59     44.21
# 40                  County Clerk's Office  (607)547-4200     -74.93     42.70
# 41          County Administrator's Office  (585)243-7040     -77.82     42.80
# 42          County Administrator's Office  (607)753-5048     -76.18     42.60
# 43                  County Clerk's Office  (607)687-8660     -76.27     42.10
# 44          County Administrator's Office  (518)565-4600     -73.45     44.70
# 45                County Manager's Office  (585)344-2550     -78.19     43.00
# 46          County Administrator's Office  (716)938-2577     -78.80     42.25
# 47          County Administrator's Office  (315)867-1112     -74.99     43.03
# 48              County Executive's Office  (607)737-2912     -76.80     42.09
# 49  Chief Administrative Officer's Office  (585)589-7053     -78.19     43.25
# 50                  County Clerk's Office  (607)746-2123     -74.92     42.28
# 51                County Manager's Office  (518)481-1693     -74.30     44.85
# 52          County Administrator's Office  (607)535-8106     -76.87     42.38
# 53                  County Clerk's Office  (607)337-1450     -75.53     42.53
# 54                  County Clerk's Office  (585)786-8810     -78.13     42.74
# 55                County Manager's Office  (315)539-1705     -76.84     42.91
# 56          County Administrator's Office  (607)664-2245     -77.32     42.33
# 57          County Administrator's Office  (315)536-5118     -77.06     42.66
# 58          County Administrator's Office  (585)268-9217     -78.03     42.22
# 59                County Manager's Office  (315)376-5355     -75.49     43.79
# 60                  County Clerk's Office  (518)548-7111     -74.41     43.47
#
#                                        county-website  \
# 0                     http://www.suffolkcountyny.gov/
# 1                            http://www.queensbp.org/
# 2                      http://www.nassaucountyny.gov/
# 3                         http://statenislandusa.com/
# 4                     http://www3.westchestergov.com/
# 5                         http://www.co.orange.ny.us/
# 6                        http://www.brooklyn-usa.org/
# 7                              http://dutchessny.gov/
# 8                            https://rocklandgov.com/
# 9                             http://co.ulster.ny.us/
# 10                              http://www2.erie.gov/
# 11                       http://www.albanycounty.com/
# 12                      http://bronxboropres.nyc.gov/
# 13                   http://www.saratogacountyny.gov/
# 14                             http://www.rensco.com/
# 15                  http://www.schenectadycounty.com/
# 16                       http://www.monroecounty.gov/
# 17                        http://www.tompkins-co.org/
# 18                              http://www.ongov.net/
# 19                               http://www.mbpo.org/
# 20                   http://www.columbiacountyny.com/
# 21                          http://www.greenegov.com/
# 22                              http://www.ocgov.net/
# 23                    http://www.co.montgomery.ny.us/
# 24                      http://www.niagaracounty.com/
# 25         http://www.co.washington.ny.us/Default.htm
# 26                     http://www.putnamcountyny.com/
# 27                         http://warrencountyny.gov/
# 28                      http://www.co.sullivan.ny.us/
# 29                        http://www.co.ontario.ny.us
# 30                        http://www.co.oswego.ny.us/
# 31                     http://www.gobroomecounty.com/
# 32                     http://www.fultoncountyny.gov/
# 33  http://www.schohariecounty-ny.gov/CountyWebSit...
# 34  http://www.co.chautauqua.ny.us/pages/default.aspx
# 35                         http://www.co.wayne.ny.us/
# 36                   http://www.madisoncounty.ny.gov/
# 37                     http://www.co.jefferson.ny.us/
# 38                        http://www.co.cayuga.ny.us/
# 39                         http://www.co.essex.ny.us/
# 40                       http://www.otsegocounty.com/
# 41              http://www.co.livingston.state.ny.us/
# 42                        http://www.cortland-co.org/
# 43                      http://www.tiogacountyny.com/
# 44                   http://www.clintoncountygov.com/
# 45                       http://www.co.genesee.ny.us/
# 46                             http://www.cattco.org/
# 47                  http://herkimercounty.org/content
# 48                      http://www.chemungcounty.com/
# 49                              http://orleansny.com/
# 50             http://www.co.delaware.ny.us/index.htm
# 51                    http://franklincony.org/content
# 52                      http://www.schuylercounty.us/
# 53                      http://www.co.chenango.ny.us/
# 54                          http://www.wyomingco.net/
# 55                        http://www.co.seneca.ny.us/
# 56                        http://www.steubencony.org/
# 57                        http://www.yatescounty.org/
# 58                         http://www.alleganyco.com/
# 59                   http://lewiscountyny.org/content
# 60                     http://www.hamiltoncounty.com/
#
#                                              location
# 0   300 Center Dr.\nRiverhead 11901\n(40.914374454...
# 1   120-55 Queens Boulevard\nNew York 11424\n(40.7...
# 2   1550 Franklin Ave.\nMineola 11501\n(40.7379915...
# 3   10 Richmond Terrace\nNew York 10301\n(40.64241...
# 4   148 Martine Ave.\nWhite Plains 10601\n(41.0305...
# 5   255 Main Street\nGoshen 10924\n(41.4062075242,...
# 6   209 Joralemon St\nNew York 11201\n(40.69274713...
# 7   22 Market St., 6Th Floor\nPoughkeepsie 12601\n...
# 8   11 New Hempstead Rd.\nNew City 10956\n(41.1479...
# 9   244 Fair Street\nKingston 12402\n(41.932692646...
# 10  95 Franklin St.\nBuffalo 14202\n(42.8839031265...
# 11  112 State Street\nAlbany 12207\n(42.6501637986...
# 12  851 Grand Concourse\nNew York 10451\n(40.82628...
# 13  40 McMaster St.\nBallston Spa 12020\n(42.99905...
# 14  1600 7Th Avenue\nTroy 12180\n(42.7289906092, -...
# 15  620 State St.\nSchenectady 12305\n(42.81015287...
# 16  39 W. Main St.\nRochester 14614\n(43.155248352...
# 17  320 N. Tioga St.\nIthaca 14850\n(42.4422942513...
# 18  421 Montgomery St.\nSyracuse 13202\n(43.046636...
# 19  1 Centre St\nNew York 10007\n(40.7129038722017...
# 20  401 State St.\nHudson 12534\n(42.2520998263, -...
# 21  411 Main St.\nCatskill 12414\n(42.2199994002, ...
# 22  800 Park Ave.\nUtica 13501\n(43.0992658144, -7...
# 23  64 Broadway\nFonda 12068\n(42.9574464463997, -...
# 24  175 Hawley St.\nLockport 14094\n(43.1695038446...
# 25  383 Broadway\nFort Edward 12828\n(43.287360490...
# 26  40 Gleneida Ave.\nCarmel 10512\n(41.4261542614...
# 27  1340 State Route 9\nLake George 12845\n(43.358...
# 28  100 North Street\nMonticello 12701\n(41.658320...
# 29  20 Ontario St.\nCanandaigua 14424\n(42.8886132...
# 30  46 E. Bridge St.\nOswego 13126\n(43.4574611999...
# 31  60 Hawley Street\nBinghamton 13902\n(42.096682...
# 32  223 W. Main St.\nJohnstown 12095\n(43.00655602...
# 33  284 Main St.\nSchoharie 12157\n(42.66374928848...
# 34  3 North Erie Street\nMayville 14757\n(42.25467...
# 35  26 Church St.\nLyons 14489\n(43.0637726417679,...
# 36  138 N. Court St\nWampsville 13163\n(43.0803839...
# 37  195 Arsenal St.\nWatertown 13601\n(43.97538516...
# 38  160 Genesee St.\nAuburn 13021\n(42.9297172717,...
# 39  7551 Court St., P.O. Box 217\nElizabethtown 12...
# 40  197 Main St.\nCooperstown 13326\n(42.700726113...
# 41  6 Court St.\nGeneseo 14454\n(42.8008513295, -7...
# 42  60 Central Ave.\nCortland 13045\n(42.600633547...
# 43  56 Main St.\nOwego 13827\n(42.1010160454932, -...
# 44  137 Margaret St.\nPlattsburgh 12901\n(44.69926...
# 45  7 Main St.\nBatavia 14020\n(42.9977584846, -78...
# 46  303 Court St.\nLittle Valley 14755\n(42.252109...
# 47  109 Mary St., Suite 1310\nHerkimer 13350\n(43....
# 48  203 Lake St.\nElmira 14902\n(42.0899894611913,...
# 49  3 S. Main St., Suite 2\nAlbion 14411\n(43.2458...
# 50  111 Main St.\nDelhi 13753\n(42.2775434125, -74...
# 51  355 W. Main St.\nMalone 12953\n(44.8489976324,...
# 52  105 Ninth St.\nWatkins Glen 14891\n(42.3771905...
# 53  5 Court St.\nNorwich 13815\n(42.5319299709, -7...
# 54  143 N. Main St.\nWarsaw 14569\n(42.74307364110...
# 55  1 DiPronio Dr.\nWaterloo 13165\n(42.9084701691...
# 56  3 E. Pulteney Square\nBath 14810\n(42.33325133...
# 57  417 Liberty St.\nPenn Yan 14527\n(42.664160716...
# 58  7 Court St.\nBelmont 14813\n(42.2248679417, -7...
# 59  7660 State St.\nLowville 13367\n(43.7888932099...
# 60  102 County View Drive\nLake Pleasant 12108\n(4...

# %%
import folium

# %%
# find the middle of the map
median_lat = counties['latitude'].median()
median_lon = counties['longitude'].median()

# create the map
m = folium.Map(location=(median_lat,median_lon), zoom_start=7, tiles='CartoDB Positron')

# add markers to the map
for index, row in counties.iterrows():
    color_match = "green" if row['total'] > 7500 else 'blue'
    tool_tip = "County: {}, Total: {:,}"\
    .format(row['county'], row['total'])
    folium.Marker(location=(row['latitude'], row['longitude']),
                  tooltip=tool_tip,
                  icon=folium.Icon(color=color_match, icon='info-sign'),
                  opacity=.4).add_to(m)

# show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c2d3f45d4c42448eaf4262a1d4bc8f08%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c2d3f45d4c42448eaf4262a1d4bc8f08%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c2d3f45d4c42448eaf4262a1d4bc8f08%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c2d3f45d4c42448eaf4262a1d4bc8f08%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B42.664161%2C%20-74.92967%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
